# %%
using CairoMakie
using DelimitedFiles
using CubicSplines
using MicroMagnetic

# %% [markdown]
# In this example, we will compute the energy barrier of a skyrmion collapse into the ferromagnetic state using the NEB method.
# Firstly, we use create_sim method to describe the studied system. For example, the system is a thin film (120x120x2 nm^3)
# with periodic boundary conditions, and three energies are considered.

# %%
mesh = FDMesh(; nx=60, ny=60, nz=1, dx=2e-9, dy=2e-9, dz=2e-9, pbc="xy")
params = Dict(:Ms => 3.84e5, :A => 3.25e-12, :D => 5.83e-4, :H => (0, 0, 120 * mT))
# Out:
# Dict{Symbol, Any} with 4 entries:
#   :A  => 3.25e-12
#   :H  => (0, 0, 95493.0)
#   :D  => 0.000583
#   :Ms => 384000.0

# %% [markdown]
# Using NEB can be divided into two stages. The first stage is to prepare the initial state and the final state. We assume that
# the initial state is a magnetic skyrmion and the final state is ferromagnetic state.

# %% [markdown]
# In this method, we will obtain a magnetic skyrmion. The skyrmion state is saved as 'skx.vts'.

# %%
function relax_skx()
    function m0_fun_skx(i, j, k, dx, dy, dz)
        r2 = (i - 30)^2 + (j - 30)^2
        if r2 < 10^2
            return (0.01, 0, -1)
        end
        return (0, 0, 1)
    end

    sim = create_sim(mesh; m0=m0_fun_skx, params...)
    relax(sim; max_steps=2000, stopping_dmdt=0.01)
    save_vtk(sim, "skx")

    return plot_m(sim)
end
# Out:
# relax_skx (generic function with 1 method)

# %% [markdown]
# We will invoke the relax_skx method to obtain a magnetic skyrmion state and plot the magnetization.

# %%
relax_skx()
# Out:
# [ Info: MicroSim has been created.
# [ Info: Exchange has been added.
# [ Info: Bulk DMI has been added.
# [ Info: Static Zeeman has been added.
# [ Info: Running Driver : MicroMagnetic.EnergyMinimization{Float64}.
# [ Info: max_dmdt is less than stopping_dmdt=0.01 @steps=176, Done!
# ┌ Warning: `arrows` are deprecated in favor of `arrows2d` and `arrows3d`.
# └ @ Makie ~/.julia/packages/Makie/aJUtI/src/basic_recipes/arrows.jl:166
# Figure()

# %% [markdown]
# The following is the second stage.

# %% [markdown]
# We need to define the initial and final state, which is stored in the init\_images list.
# Note that any acceptable object, such as a function, a tuple, or an array, can be used.
# Moreover, the init\_images list could contain the intermediate state if you have one.

# %%
init_images = [read_vtk("skx.vts"), (0, 0, 1)];

# %% [markdown]
# We need an interpolation array to specify how many images will be used in the NEB simulation.
# Note the length of the interpolation array is the length of init\_images minus one. For example,
# if init\_images = [read_vtk("skx.vts"), read_vtk("skx2.vts"), (0, 0, 1)], the length of interpolation should be 2,
# i.e., something like interpolation = [5,5].

# %%
interpolation = [6];

# %% [markdown]
# To use the NEB, we use the create_sim method to create a Sim instance.

# %%
sim = create_sim(mesh; params...);
# Out:
# [ Info: MicroSim has been created.
# [ Info: Exchange has been added.
# [ Info: Bulk DMI has been added.
# [ Info: Static Zeeman has been added.

# %% [markdown]
# We create the NEB instance and set the spring_constant, the driver could be "SD" or "LLG"

# %%
neb = NEB(sim, init_images, interpolation; name="skx_fm", driver="SD");

# %% [markdown]
# neb.spring_constant = 1e7

# %% [markdown]
# Relax the whole system

# %%
relax(neb; stopping_dmdt=0.1, save_vtk_every=1000, max_steps=5000)
# Out:
# [ Info: Running Driver : MicroMagnetic.EnergyMinimization{Float64}.
# [ Info: step =    0  step_size=9.049774e-16  max_dmdt=4.099193e+04
# [ Info: step =    1  step_size=1.329080e-12  max_dmdt=3.700535e+04
# [ Info: step =    2  step_size=5.936955e-13  max_dmdt=3.709928e+04
# [ Info: step =    3  step_size=5.111950e-13  max_dmdt=1.485783e+04
# [ Info: step =    4  step_size=3.925834e-13  max_dmdt=1.012748e+04
# [ Info: step =    5  step_size=1.570271e-12  max_dmdt=8.310125e+03
# [ Info: step =    6  step_size=2.019970e-12  max_dmdt=5.657644e+03
# [ Info: step =    7  step_size=3.116170e-12  max_dmdt=5.329243e+03
# [ Info: step =    8  step_size=3.549052e-13  max_dmdt=3.942310e+04
# [ Info: step =    9  step_size=3.525064e-13  max_dmdt=4.789110e+03
# [ Info: step =   10  step_size=4.221884e-13  max_dmdt=1.776622e+03
# [ Info: step =   11  step_size=5.167675e-12  max_dmdt=7.198704e+02
# [ Info: step =   12  step_size=3.240469e-12  max_dmdt=4.149923e+03
# [ Info: step =   13  step_size=1.193528e-12  max_dmdt=1.570993e+04
# [ Info: step =   14  step_size=5.436409e-13  max_dmdt=1.288352e+04
# [ Info: step =   15  step_size=4.387748e-13  max_dmdt=1.817773e+03
# [ Info: step =   16  step_size=3.414906e-13  max_dmdt=6.441648e+02
# [ Info: step =   17  step_size=6.956702e-13  max_dmdt=4.071795e+02
# [ Info: step =   18  step_size=1.598574e-12  max_dmdt=1.664021e+02
# [ Info: step =   19  step_size=1.914136e-11  max_dmdt=1.552519e+02
# [ Info: step =   20  step_size=7.221136e-13  max_dmdt=2.246241e+03
# [ Info: step =   21  step_size=3.353805e-13  max_dmdt=2.641650e+03
# [ Info: step =   22  step_size=3.307397e-13  max_dmdt=1.303203e+02
# [ Info: step =   23  step_size=2.099200e-12  max_dmdt=1.304802e+02
# [ Info: step =   24  step_size=3.536396e-12  max_dmdt=1.130421e+02
# [ Info: step =   25  step_size=7.736391e-12  max_dmdt=4.435751e+02
# [ Info: step =   26  step_size=3.949128e-13  max_dmdt=8.421233e+03
# [ Info: step =   27  step_size=3.852619e-13  max_dmdt=6.304261e+02
# [ Info: step =   28  step_size=4.023992e-13  max_dmdt=3.961914e+02
# [ Info: step =   29  step_size=9.298038e-13  max_dmdt=2.323783e+02
# [ Info: step =   30  step_size=6.745695e-13  max_dmdt=8.908178e+01
# [ Info: step =   31  step_size=5.327524e-12  max_dmdt=8.171801e+01
# [ Info: step =   32  step_size=3.666791e-13  max_dmdt=2.740701e+02
# [ Info: step =   33  step_size=3.478119e-13  max_dmdt=8.273253e+01
# [ Info: step =   34  step_size=3.359016e-13  max_dmdt=8.248860e+01
# [ Info: step =   35  step_size=4.262748e-11  max_dmdt=8.240988e+01
# [ Info: step =   36  step_size=1.266394e-11  max_dmdt=1.675768e+02
# [ Info: step =   37  step_size=7.775874e-13  max_dmdt=3.507712e+03
# [ Info: step =   38  step_size=5.075722e-13  max_dmdt=1.618881e+03
# [ Info: step =   39  step_size=4.323719e-13  max_dmdt=3.246418e+02
# [ Info: step =   40  step_size=3.279101e-13  max_dmdt=1.319661e+02
# [ Info: step =   41  step_size=3.883385e-13  max_dmdt=8.392703e+01
# [ Info: step =   42  step_size=1.125040e-12  max_dmdt=8.113580e+01
# [ Info: step =   43  step_size=1.080057e-11  max_dmdt=9.254030e+01
# [ Info: step =   44  step_size=1.488821e-12  max_dmdt=1.636254e+02
# [ Info: step =   45  step_size=1.169358e-12  max_dmdt=2.137862e+02
# [ Info: step =   46  step_size=3.632127e-13  max_dmdt=2.455912e+02
# [ Info: step =   47  step_size=3.545392e-13  max_dmdt=1.006524e+02
# [ Info: step =   48  step_size=3.769530e-13  max_dmdt=1.042090e+02
# [ Info: step =   49  step_size=1.786631e-11  max_dmdt=1.056836e+02
# [ Info: step =   50  step_size=4.926820e-13  max_dmdt=3.245964e+02
# [ Info: step =   51  step_size=7.580481e-13  max_dmdt=1.088874e+02
# [ Info: step =   52  step_size=4.518610e-13  max_dmdt=1.048337e+02
# [ Info: step =   53  step_size=4.925479e-12  max_dmdt=1.069007e+02
# [ Info: step =   54  step_size=3.293414e-13  max_dmdt=1.213031e+02
# [ Info: step =   55  step_size=4.900470e-13  max_dmdt=1.198807e+02
# [ Info: step =   56  step_size=4.122541e-13  max_dmdt=1.188659e+02
# [ Info: step =   57  step_size=5.924843e-10  max_dmdt=1.010812e+02
# [ Info: step =   58  step_size=1.484692e-12  max_dmdt=8.262511e+03
# [ Info: step =   59  step_size=1.409660e-12  max_dmdt=4.670424e+03
# [ Info: step =   60  step_size=3.701402e-13  max_dmdt=6.760246e+03
# [ Info: step =   61  step_size=3.415678e-13  max_dmdt=2.308379e+03
# [ Info: step =   62  step_size=3.657298e-13  max_dmdt=1.188205e+03
# [ Info: step =   63  step_size=3.147253e-12  max_dmdt=7.350115e+02
# [ Info: step =   64  step_size=1.572181e-12  max_dmdt=1.629735e+03
# [ Info: step =   65  step_size=1.473030e-12  max_dmdt=1.945781e+03
# [ Info: step =   66  step_size=5.186714e-13  max_dmdt=2.641987e+03
# [ Info: step =   67  step_size=5.010938e-13  max_dmdt=5.664727e+02
# [ Info: step =   68  step_size=3.327301e-13  max_dmdt=5.162176e+02
# [ Info: step =   69  step_size=1.413484e-12  max_dmdt=5.053360e+02
# [ Info: step =   70  step_size=2.492834e-12  max_dmdt=4.770041e+02
# [ Info: step =   71  step_size=4.571980e-11  max_dmdt=4.881422e+02
# [ Info: step =   72  step_size=3.500822e-13  max_dmdt=1.207764e+04
# [ Info: step =   73  step_size=3.483080e-13  max_dmdt=3.830940e+03
# [ Info: step =   74  step_size=5.502137e-13  max_dmdt=1.700510e+03
# [ Info: step =   75  step_size=9.901846e-13  max_dmdt=4.393665e+02
# [ Info: step =   76  step_size=9.347140e-13  max_dmdt=3.801446e+02
# [ Info: step =   77  step_size=9.551790e-12  max_dmdt=3.422650e+02
# [ Info: step =   78  step_size=4.154694e-13  max_dmdt=1.179404e+03
# [ Info: step =   79  step_size=3.440745e-13  max_dmdt=4.927557e+02
# [ Info: step =   80  step_size=3.296596e-13  max_dmdt=4.393875e+02
# [ Info: step =   81  step_size=1.163163e-11  max_dmdt=4.056406e+02
# [ Info: step =   82  step_size=2.176173e-12  max_dmdt=9.648583e+02
# [ Info: step =   83  step_size=1.390109e-12  max_dmdt=1.838382e+03
# [ Info: step =   84  step_size=6.308046e-13  max_dmdt=1.641550e+03
# [ Info: step =   85  step_size=6.356121e-13  max_dmdt=3.215392e+02
# [ Info: step =   86  step_size=3.461441e-13  max_dmdt=3.321165e+02
# [ Info: step =   87  step_size=8.478272e-13  max_dmdt=3.323113e+02
# [ Info: step =   88  step_size=4.671657e-13  max_dmdt=3.346566e+02
# [ Info: step =   89  step_size=3.966516e-11  max_dmdt=3.314725e+02
# [ Info: step =   90  step_size=6.680978e-13  max_dmdt=6.520150e+02
# [ Info: step =   91  step_size=3.459219e-13  max_dmdt=6.800725e+02
# [ Info: step =   92  step_size=3.253960e-13  max_dmdt=2.247793e+02
# [ Info: step =   93  step_size=3.499423e-12  max_dmdt=2.205587e+02
# [ Info: step =   94  step_size=4.009072e-12  max_dmdt=2.655260e+02
# [ Info: step =   95  step_size=4.029813e-11  max_dmdt=2.861795e+02
# [ Info: step =   96  step_size=4.326123e-13  max_dmdt=1.400169e+04
# [ Info: step =   97  step_size=4.138762e-13  max_dmdt=3.093637e+03
# [ Info: step =   98  step_size=4.028880e-13  max_dmdt=1.831050e+03
# [ Info: step =   99  step_size=1.024219e-12  max_dmdt=1.206043e+03
# [ Info: step =  100  step_size=1.058774e-12  max_dmdt=2.582756e+02
# [ Info: step =  101  step_size=1.527953e-12  max_dmdt=1.597297e+02
# [ Info: step =  102  step_size=3.283146e-13  max_dmdt=4.404660e+02
# [ Info: step =  103  step_size=3.414874e-13  max_dmdt=1.446996e+02
# [ Info: step =  104  step_size=5.606426e-13  max_dmdt=1.436164e+02
# [ Info: step =  105  step_size=1.223443e-10  max_dmdt=1.416727e+02
# [ Info: step =  106  step_size=7.987922e-12  max_dmdt=7.982623e+02
# [ Info: step =  107  step_size=2.442182e-12  max_dmdt=3.892843e+03
# [ Info: step =  108  step_size=3.527661e-13  max_dmdt=2.114960e+04
# [ Info: step =  109  step_size=3.492589e-13  max_dmdt=2.538490e+03
# [ Info: step =  110  step_size=4.233394e-13  max_dmdt=1.334233e+03
# [ Info: step =  111  step_size=8.159623e-13  max_dmdt=6.201254e+02
# [ Info: step =  112  step_size=8.611101e-13  max_dmdt=2.595986e+02
# [ Info: step =  113  step_size=2.764864e-12  max_dmdt=1.873654e+02
# [ Info: step =  114  step_size=4.853059e-13  max_dmdt=2.204469e+02
# [ Info: step =  115  step_size=3.608888e-13  max_dmdt=1.206517e+02
# [ Info: step =  116  step_size=3.278621e-13  max_dmdt=6.897364e+01
# [ Info: step =  117  step_size=7.281997e-12  max_dmdt=6.684303e+01
# [ Info: step =  118  step_size=3.766267e-12  max_dmdt=9.565977e+01
# [ Info: step =  119  step_size=6.484894e-12  max_dmdt=2.261230e+02
# [ Info: step =  120  step_size=5.421531e-13  max_dmdt=1.557285e+03
# [ Info: step =  121  step_size=4.531629e-13  max_dmdt=3.131037e+02
# [ Info: step =  122  step_size=3.374140e-13  max_dmdt=2.121190e+02
# [ Info: step =  123  step_size=4.480025e-13  max_dmdt=1.390005e+02
# [ Info: step =  124  step_size=1.033682e-12  max_dmdt=1.109847e+02
# [ Info: step =  125  step_size=6.307885e-12  max_dmdt=6.161515e+01
# [ Info: step =  126  step_size=5.999574e-13  max_dmdt=8.381316e+01
# [ Info: step =  127  step_size=5.311904e-13  max_dmdt=6.593208e+01
# [ Info: step =  128  step_size=3.287578e-13  max_dmdt=5.987921e+01
# [ Info: step =  129  step_size=9.305177e-13  max_dmdt=5.848838e+01
# [ Info: step =  130  step_size=1.799375e-12  max_dmdt=5.516578e+01
# [ Info: step =  131  step_size=1.353876e-10  max_dmdt=5.594490e+01
# [ Info: step =  132  step_size=3.843453e-13  max_dmdt=1.735172e+03
# [ Info: step =  133  step_size=3.287662e-13  max_dmdt=3.036001e+02
# [ Info: step =  134  step_size=3.246796e-13  max_dmdt=1.493557e+02
# [ Info: step =  135  step_size=7.435878e-12  max_dmdt=1.305452e+02
# [ Info: step =  136  step_size=1.785766e-12  max_dmdt=2.062066e+02
# [ Info: step =  137  step_size=1.795486e-12  max_dmdt=2.018889e+02
# [ Info: step =  138  step_size=6.800091e-13  max_dmdt=2.346032e+02
# [ Info: step =  139  step_size=7.727939e-13  max_dmdt=7.848108e+01
# [ Info: step =  140  step_size=3.736708e-13  max_dmdt=7.459744e+01
# [ Info: step =  141  step_size=9.780916e-13  max_dmdt=6.261742e+01
# [ Info: step =  142  step_size=6.430660e-13  max_dmdt=6.348247e+01
# [ Info: step =  143  step_size=3.292022e-11  max_dmdt=6.264293e+01
# [ Info: step =  144  step_size=3.976965e-13  max_dmdt=4.610518e+02
# [ Info: step =  145  step_size=3.289196e-13  max_dmdt=1.199023e+02
# [ Info: step =  146  step_size=3.250962e-13  max_dmdt=6.686438e+01
# [ Info: step =  147  step_size=5.786551e-11  max_dmdt=6.626319e+01
# [ Info: step =  148  step_size=6.992404e-12  max_dmdt=3.013187e+02
# [ Info: step =  149  step_size=2.173542e-12  max_dmdt=1.949887e+03
# [ Info: step =  150  step_size=4.835437e-13  max_dmdt=5.497343e+03
# [ Info: step =  151  step_size=4.397657e-13  max_dmdt=3.474769e+02
# [ Info: step =  152  step_size=3.694469e-13  max_dmdt=2.263183e+02
# [ Info: step =  153  step_size=6.262718e-13  max_dmdt=1.709527e+02
# [ Info: step =  154  step_size=1.099530e-12  max_dmdt=1.060598e+02
# [ Info: step =  155  step_size=3.499197e-12  max_dmdt=5.529338e+01
# [ Info: step =  156  step_size=3.682097e-13  max_dmdt=1.203317e+02
# [ Info: step =  157  step_size=3.500259e-13  max_dmdt=2.943876e+01
# [ Info: step =  158  step_size=3.369433e-13  max_dmdt=2.668365e+01
# [ Info: step =  159  step_size=4.274449e-11  max_dmdt=2.611906e+01
# [ Info: step =  160  step_size=4.109793e-12  max_dmdt=2.144973e+02
# [ Info: step =  161  step_size=1.403035e-12  max_dmdt=5.510772e+02
# [ Info: step =  162  step_size=6.039124e-13  max_dmdt=3.182154e+02
# [ Info: step =  163  step_size=3.546108e-13  max_dmdt=1.559207e+02
# [ Info: step =  164  step_size=3.250977e-13  max_dmdt=4.438244e+01
# [ Info: step =  165  step_size=7.446768e-13  max_dmdt=2.872098e+01
# [ Info: step =  166  step_size=9.783702e-13  max_dmdt=1.294987e+01
# [ Info: step =  167  step_size=4.570358e-11  max_dmdt=1.285182e+01
# [ Info: step =  168  step_size=2.522954e-12  max_dmdt=1.105637e+02
# [ Info: step =  169  step_size=5.113466e-13  max_dmdt=4.443910e+02
# [ Info: step =  170  step_size=4.041655e-13  max_dmdt=8.022145e+01
# [ Info: step =  171  step_size=3.443731e-13  max_dmdt=1.881356e+01
# [ Info: step =  172  step_size=3.295351e-13  max_dmdt=1.077601e+01
# [ Info: step =  173  step_size=8.546644e-12  max_dmdt=9.838991e+00
# [ Info: step =  174  step_size=1.827396e-12  max_dmdt=3.302947e+01
# [ Info: step =  175  step_size=1.749884e-12  max_dmdt=2.279369e+01
# [ Info: step =  176  step_size=5.354536e-13  max_dmdt=5.185103e+01
# [ Info: step =  177  step_size=5.244493e-13  max_dmdt=1.402527e+01
# [ Info: step =  178  step_size=3.457370e-13  max_dmdt=1.097291e+01
# [ Info: step =  179  step_size=2.018178e-12  max_dmdt=9.990696e+00
# [ Info: step =  180  step_size=9.149474e-13  max_dmdt=8.713811e+00
# [ Info: step =  181  step_size=1.217230e-11  max_dmdt=8.708278e+00
# [ Info: step =  182  step_size=3.316525e-13  max_dmdt=9.402002e+01
# [ Info: step =  183  step_size=3.288298e-13  max_dmdt=9.606295e+00
# [ Info: step =  184  step_size=3.887928e-13  max_dmdt=9.913880e+00
# [ Info: step =  185  step_size=4.608628e-11  max_dmdt=1.007719e+01
# [ Info: step =  186  step_size=2.118481e-12  max_dmdt=3.426736e+01
# [ Info: step =  187  step_size=9.045144e-13  max_dmdt=5.111429e+01
# [ Info: step =  188  step_size=4.678385e-13  max_dmdt=3.818242e+01
# [ Info: step =  189  step_size=4.677637e-13  max_dmdt=1.824589e+01
# [ Info: step =  190  step_size=3.511487e-13  max_dmdt=1.707003e+01
# [ Info: step =  191  step_size=9.139834e-12  max_dmdt=1.671051e+01
# [ Info: step =  192  step_size=9.204684e-13  max_dmdt=1.453528e+01
# [ Info: step =  193  step_size=1.844529e-12  max_dmdt=1.408470e+01
# [ Info: step =  194  step_size=3.268557e-13  max_dmdt=3.687653e+01
# [ Info: step =  195  step_size=3.500478e-13  max_dmdt=1.646163e+01
# [ Info: step =  196  step_size=4.735426e-13  max_dmdt=1.621323e+01
# [ Info: step =  197  step_size=3.853977e-10  max_dmdt=1.603839e+01
# [ Info: step =  198  step_size=1.985498e-12  max_dmdt=1.420681e+02
# [ Info: step =  199  step_size=8.660301e-13  max_dmdt=2.747920e+02
# [ Info: step =  200  step_size=4.608885e-13  max_dmdt=1.612579e+02
# [ Info: step =  201  step_size=3.639984e-13  max_dmdt=5.210937e+01
# [ Info: step =  202  step_size=3.298654e-13  max_dmdt=2.387915e+01
# [ Info: step =  203  step_size=4.404621e-12  max_dmdt=2.356504e+01
# [ Info: step =  204  step_size=1.587901e-12  max_dmdt=3.719473e+01
# [ Info: step =  205  step_size=2.680114e-12  max_dmdt=4.228843e+01
# [ Info: step =  206  step_size=5.763778e-13  max_dmdt=1.226760e+02
# [ Info: step =  207  step_size=5.491148e-13  max_dmdt=3.551288e+01
# [ Info: step =  208  step_size=3.372341e-13  max_dmdt=2.167193e+01
# [ Info: step =  209  step_size=8.057947e-13  max_dmdt=1.892584e+01
# [ Info: step =  210  step_size=1.028778e-12  max_dmdt=1.833625e+01
# [ Info: step =  211  step_size=5.775884e-11  max_dmdt=1.869486e+01
# [ Info: step =  212  step_size=4.244700e-13  max_dmdt=3.423304e+02
# [ Info: step =  213  step_size=3.288773e-13  max_dmdt=9.880720e+01
# [ Info: step =  214  step_size=3.246636e-13  max_dmdt=8.788168e+00
# [ Info: step =  215  step_size=1.138885e-11  max_dmdt=8.793573e+00
# [ Info: step =  216  step_size=3.284963e-12  max_dmdt=1.643659e+01
# [ Info: step =  217  step_size=1.525685e-12  max_dmdt=6.957391e+01
# [ Info: step =  218  step_size=5.664852e-13  max_dmdt=9.725335e+01
# [ Info: step =  219  step_size=4.990936e-13  max_dmdt=3.075357e+01
# [ Info: step =  220  step_size=4.110572e-13  max_dmdt=1.088565e+01
# [ Info: step =  221  step_size=1.832064e-12  max_dmdt=7.732775e+00
# [ Info: step =  222  step_size=1.048120e-12  max_dmdt=7.675651e+00
# [ Info: step =  223  step_size=1.428642e-11  max_dmdt=7.561169e+00
# [ Info: step =  224  step_size=4.131347e-13  max_dmdt=6.975478e+01
# [ Info: step =  225  step_size=3.851041e-13  max_dmdt=1.286155e+01
# [ Info: step =  226  step_size=3.781442e-13  max_dmdt=7.995298e+00
# [ Info: step =  227  step_size=6.316153e-12  max_dmdt=6.777615e+00
# [ Info: step =  228  step_size=8.580577e-13  max_dmdt=1.645048e+01
# [ Info: step =  229  step_size=1.067960e-12  max_dmdt=7.482064e+00
# [ Info: step =  230  step_size=3.399773e-13  max_dmdt=1.051876e+01
# [ Info: step =  231  step_size=4.676446e-13  max_dmdt=6.391249e+00
# [ Info: step =  232  step_size=5.277663e-13  max_dmdt=6.357432e+00
# [ Info: step =  233  step_size=9.779559e-11  max_dmdt=6.324966e+00
# [ Info: step =  234  step_size=2.318630e-12  max_dmdt=3.948118e+01
# [ Info: step =  235  step_size=3.409406e-13  max_dmdt=2.209987e+02
# [ Info: step =  236  step_size=3.250126e-13  max_dmdt=1.672606e+01
# [ Info: step =  237  step_size=4.888390e-13  max_dmdt=1.191072e+01
# [ Info: step =  238  step_size=6.918483e-13  max_dmdt=1.086320e+01
# [ Info: step =  239  step_size=3.914242e-11  max_dmdt=1.184651e+01
# [ Info: step =  240  step_size=1.184590e-11  max_dmdt=1.304800e+01
# [ Info: step =  241  step_size=6.001834e-12  max_dmdt=5.845388e+01
# [ Info: step =  242  step_size=3.430579e-13  max_dmdt=8.749863e+02
# [ Info: step =  243  step_size=3.331806e-13  max_dmdt=1.161919e+02
# [ Info: step =  244  step_size=4.729778e-13  max_dmdt=4.908380e+01
# [ Info: step =  245  step_size=7.380620e-13  max_dmdt=3.440060e+01
# [ Info: step =  246  step_size=7.605140e-13  max_dmdt=2.057294e+01
# [ Info: step =  247  step_size=3.920284e-12  max_dmdt=1.442971e+01
# [ Info: step =  248  step_size=4.509784e-13  max_dmdt=1.720915e+01
# [ Info: step =  249  step_size=4.412331e-13  max_dmdt=9.430208e+00
# [ Info: step =  250  step_size=3.382663e-13  max_dmdt=8.989738e+00
# [ Info: step =  251  step_size=4.825073e-12  max_dmdt=8.829313e+00
# [ Info: step =  252  step_size=1.413432e-12  max_dmdt=1.676689e+01
# [ Info: step =  253  step_size=5.519410e-12  max_dmdt=9.612467e+00
# [ Info: step =  254  step_size=3.272215e-13  max_dmdt=5.351130e+01
# [ Info: step =  255  step_size=3.298615e-13  max_dmdt=1.162892e+01
# [ Info: step =  256  step_size=5.788248e-13  max_dmdt=1.121780e+01
# [ Info: step =  257  step_size=4.395448e-11  max_dmdt=1.064119e+01
# [ Info: step =  258  step_size=2.617302e-12  max_dmdt=2.888076e+01
# [ Info: step =  259  step_size=1.207401e-12  max_dmdt=3.685976e+01
# [ Info: step =  260  step_size=4.481539e-13  max_dmdt=4.374181e+01
# [ Info: step =  261  step_size=3.827716e-13  max_dmdt=1.358352e+01
# [ Info: step =  262  step_size=3.593122e-13  max_dmdt=8.629257e+00
# [ Info: step =  263  step_size=4.344476e-12  max_dmdt=7.740179e+00
# [ Info: step =  264  step_size=7.647503e-13  max_dmdt=9.978001e+00
# [ Info: step =  265  step_size=1.580512e-12  max_dmdt=8.066943e+00
# [ Info: step =  266  step_size=3.363496e-13  max_dmdt=9.748694e+00
# [ Info: step =  267  step_size=4.828360e-13  max_dmdt=7.114837e+00
# [ Info: step =  268  step_size=5.656573e-13  max_dmdt=7.274512e+00
# [ Info: step =  269  step_size=1.275260e-10  max_dmdt=7.322466e+00
# [ Info: step =  270  step_size=1.742969e-12  max_dmdt=3.668692e+01
# [ Info: step =  271  step_size=3.273064e-13  max_dmdt=1.576777e+02
# [ Info: step =  272  step_size=3.245440e-13  max_dmdt=5.663925e+00
# [ Info: step =  273  step_size=8.949083e-13  max_dmdt=3.502009e+00
# [ Info: step =  274  step_size=6.961255e-13  max_dmdt=2.426027e+00
# [ Info: step =  275  step_size=1.687689e-11  max_dmdt=2.366564e+00
# [ Info: step =  276  step_size=1.330790e-12  max_dmdt=4.842727e+00
# [ Info: step =  277  step_size=5.087072e-13  max_dmdt=7.504921e+00
# [ Info: step =  278  step_size=3.835698e-13  max_dmdt=3.510463e+00
# [ Info: step =  279  step_size=5.498334e-13  max_dmdt=2.144059e+00
# [ Info: step =  280  step_size=5.588807e-13  max_dmdt=2.146020e+00
# [ Info: step =  281  step_size=8.539946e-11  max_dmdt=2.138685e+00
# [ Info: step =  282  step_size=2.298164e-12  max_dmdt=1.650764e+01
# [ Info: step =  283  step_size=3.694260e-13  max_dmdt=8.320984e+01
# [ Info: step =  284  step_size=3.529795e-13  max_dmdt=4.903123e+00
# [ Info: step =  285  step_size=4.552594e-13  max_dmdt=3.477495e+00
# [ Info: step =  286  step_size=5.129574e-13  max_dmdt=3.257880e+00
# [ Info: step =  287  step_size=5.774380e-11  max_dmdt=3.154841e+00
# [ Info: step =  288  step_size=1.454139e-12  max_dmdt=1.339358e+01
# [ Info: step =  289  step_size=4.673626e-13  max_dmdt=2.601074e+01
# [ Info: step =  290  step_size=3.257261e-13  max_dmdt=1.183396e+01
# [ Info: step =  291  step_size=3.495372e-13  max_dmdt=8.338032e+00
# [ Info: step =  292  step_size=2.475824e-12  max_dmdt=7.955615e+00
# [ Info: step =  293  step_size=8.762731e-12  max_dmdt=5.531290e+00
# [ Info: step =  294  step_size=1.523910e-12  max_dmdt=1.250999e+01
# [ Info: step =  295  step_size=1.127485e-12  max_dmdt=6.146578e+00
# [ Info: step =  296  step_size=4.278752e-13  max_dmdt=5.827388e+00
# [ Info: step =  297  step_size=3.954221e-13  max_dmdt=4.027185e+00
# [ Info: step =  298  step_size=3.369704e-13  max_dmdt=3.734266e+00
# [ Info: step =  299  step_size=9.091231e-12  max_dmdt=3.628473e+00
# [ Info: step =  300  step_size=1.393922e-12  max_dmdt=4.157715e+00
# [ Info: step =  301  step_size=1.739673e-12  max_dmdt=4.857812e+00
# [ Info: step =  302  step_size=4.161072e-13  max_dmdt=5.876302e+00
# [ Info: step =  303  step_size=3.941307e-13  max_dmdt=3.538757e+00
# [ Info: step =  304  step_size=3.523335e-13  max_dmdt=3.318366e+00
# [ Info: step =  305  step_size=7.234845e-12  max_dmdt=3.448715e+00
# [ Info: step =  306  step_size=7.704636e-13  max_dmdt=4.769449e+00
# [ Info: step =  307  step_size=1.235750e-12  max_dmdt=3.411462e+00
# [ Info: step =  308  step_size=3.360226e-13  max_dmdt=3.544763e+00
# [ Info: step =  309  step_size=5.433892e-13  max_dmdt=3.491599e+00
# [ Info: step =  310  step_size=5.446464e-13  max_dmdt=3.450742e+00
# [ Info: step =  311  step_size=1.791563e-10  max_dmdt=3.442865e+00
# [ Info: step =  312  step_size=1.062591e-12  max_dmdt=1.848222e+01
# [ Info: step =  313  step_size=3.270951e-13  max_dmdt=4.195367e+01
# [ Info: step =  314  step_size=3.245664e-13  max_dmdt=2.947791e+00
# [ Info: step =  315  step_size=3.511520e-12  max_dmdt=2.729376e+00
# [ Info: step =  316  step_size=1.826607e-12  max_dmdt=1.909669e+00
# [ Info: step =  317  step_size=2.857244e-12  max_dmdt=2.732016e+00
# [ Info: step =  318  step_size=6.630092e-13  max_dmdt=7.207111e+00
# [ Info: step =  319  step_size=7.172446e-13  max_dmdt=1.696886e+00
# [ Info: step =  320  step_size=4.339093e-13  max_dmdt=1.627954e+00
# [ Info: step =  321  step_size=1.718858e-11  max_dmdt=1.581778e+00
# [ Info: step =  322  step_size=1.187508e-12  max_dmdt=1.653308e+00
# [ Info: step =  323  step_size=4.208609e-13  max_dmdt=3.928487e+00
# [ Info: step =  324  step_size=3.350717e-13  max_dmdt=1.264106e+00
# [ Info: step =  325  step_size=5.183556e-13  max_dmdt=1.239225e+00
# [ Info: step =  326  step_size=1.219940e-12  max_dmdt=1.238529e+00
# [ Info: step =  327  step_size=9.726869e-11  max_dmdt=1.213903e+00
# [ Info: step =  328  step_size=8.305113e-13  max_dmdt=1.105942e+01
# [ Info: step =  329  step_size=3.384964e-13  max_dmdt=1.627145e+01
# [ Info: step =  330  step_size=3.344043e-13  max_dmdt=9.571812e-01
# [ Info: step =  331  step_size=5.769848e-13  max_dmdt=7.278776e-01
# [ Info: step =  332  step_size=9.823139e-13  max_dmdt=7.065863e-01
# [ Info: step =  333  step_size=2.583174e-11  max_dmdt=6.705990e-01
# [ Info: step =  334  step_size=6.762419e-13  max_dmdt=2.866053e+00
# [ Info: step =  335  step_size=3.823971e-13  max_dmdt=2.938936e+00
# [ Info: step =  336  step_size=3.530322e-13  max_dmdt=1.129628e+00
# [ Info: step =  337  step_size=1.967664e-12  max_dmdt=9.419862e-01
# [ Info: step =  338  step_size=3.322552e-12  max_dmdt=8.534149e-01
# [ Info: step =  339  step_size=5.543077e-12  max_dmdt=1.734703e+00
# [ Info: step =  340  step_size=3.252116e-13  max_dmdt=2.044650e+01
# [ Info: step =  341  step_size=3.252659e-13  max_dmdt=6.327841e-01
# [ Info: step =  342  step_size=3.663698e-13  max_dmdt=5.933319e-01
# [ Info: step =  343  step_size=1.685845e-10  max_dmdt=5.917459e-01
# [ Info: step =  344  step_size=2.203584e-12  max_dmdt=4.028543e+00
# [ Info: step =  345  step_size=8.984810e-13  max_dmdt=1.191980e+01
# [ Info: step =  346  step_size=4.737068e-13  max_dmdt=1.180717e+01
# [ Info: step =  347  step_size=4.887568e-13  max_dmdt=1.062030e+00
# [ Info: step =  348  step_size=3.949425e-13  max_dmdt=9.359305e-01
# [ Info: step =  349  step_size=1.567148e-11  max_dmdt=9.255981e-01
# [ Info: step =  350  step_size=3.139019e-12  max_dmdt=1.035657e+00
# [ Info: step =  351  step_size=9.333468e-13  max_dmdt=3.950891e+00
# [ Info: step =  352  step_size=3.382431e-13  max_dmdt=6.760614e+00
# [ Info: step =  353  step_size=3.372791e-13  max_dmdt=8.030819e-01
# [ Info: step =  354  step_size=3.847178e-13  max_dmdt=7.029024e-01
# [ Info: step =  355  step_size=2.913136e-11  max_dmdt=6.726901e-01
# [ Info: step =  356  step_size=1.666394e-12  max_dmdt=2.890890e+00
# [ Info: step =  357  step_size=7.612432e-13  max_dmdt=3.390752e+00
# [ Info: step =  358  step_size=6.043532e-13  max_dmdt=1.208334e+00
# [ Info: step =  359  step_size=7.289553e-13  max_dmdt=8.745648e-01
# [ Info: step =  360  step_size=3.371825e-13  max_dmdt=9.340768e-01
# [ Info: step =  361  step_size=7.868944e-13  max_dmdt=5.224421e-01
# [ Info: step =  362  step_size=1.409280e-12  max_dmdt=5.357974e-01
# [ Info: step =  363  step_size=5.026688e-11  max_dmdt=5.270996e-01
# [ Info: step =  364  step_size=3.711298e-13  max_dmdt=1.630441e+01
# [ Info: step =  365  step_size=3.333526e-13  max_dmdt=2.619797e+00
# [ Info: step =  366  step_size=3.297805e-13  max_dmdt=8.672315e-01
# [ Info: step =  367  step_size=5.920243e-12  max_dmdt=8.109744e-01
# [ Info: step =  368  step_size=4.370463e-12  max_dmdt=1.019169e+00
# [ Info: step =  369  step_size=2.302113e-12  max_dmdt=4.001085e+00
# [ Info: step =  370  step_size=4.561890e-13  max_dmdt=1.793259e+01
# [ Info: step =  371  step_size=4.535915e-13  max_dmdt=1.023469e+00
# [ Info: step =  372  step_size=3.771224e-13  max_dmdt=5.103888e-01
# [ Info: step =  373  step_size=2.247210e-12  max_dmdt=5.090023e-01
# [ Info: step =  374  step_size=4.542585e-13  max_dmdt=6.376590e-01
# [ Info: step =  375  step_size=2.564055e-12  max_dmdt=5.673104e-01
# [ Info: step =  376  step_size=3.452748e-13  max_dmdt=7.295312e-01
# [ Info: step =  377  step_size=6.382144e-13  max_dmdt=5.194983e-01
# [ Info: step =  378  step_size=4.305029e-13  max_dmdt=5.552455e-01
# [ Info: step =  379  step_size=6.400137e-11  max_dmdt=5.513021e-01
# [ Info: step =  380  step_size=1.147659e-12  max_dmdt=2.056336e+00
# [ Info: step =  381  step_size=3.386003e-13  max_dmdt=4.970153e+00
# [ Info: step =  382  step_size=3.245010e-13  max_dmdt=6.592664e-01
# [ Info: step =  383  step_size=1.456978e-12  max_dmdt=6.343447e-01
# [ Info: step =  384  step_size=1.906503e-12  max_dmdt=6.517629e-01
# [ Info: step =  385  step_size=2.248882e-10  max_dmdt=6.763824e-01
# [ Info: step =  386  step_size=5.935512e-13  max_dmdt=2.368757e+01
# [ Info: step =  387  step_size=5.325694e-13  max_dmdt=1.919841e+00
# [ Info: step =  388  step_size=4.044651e-13  max_dmdt=1.057903e+00
# [ Info: step =  389  step_size=5.600495e-13  max_dmdt=9.958417e-01
# [ Info: step =  390  step_size=6.563741e-13  max_dmdt=1.004279e+00
# [ Info: step =  391  step_size=1.121373e-11  max_dmdt=9.744864e-01
# [ Info: step =  392  step_size=1.254635e-12  max_dmdt=9.597627e-01
# [ Info: step =  393  step_size=3.891125e-13  max_dmdt=2.251684e+00
# [ Info: step =  394  step_size=3.549158e-13  max_dmdt=7.995228e-01
# [ Info: step =  395  step_size=7.791417e-13  max_dmdt=8.267484e-01
# [ Info: step =  396  step_size=8.753320e-13  max_dmdt=8.290147e-01
# [ Info: step =  397  step_size=3.292147e-11  max_dmdt=8.217692e-01
# [ Info: step =  398  step_size=3.918510e-13  max_dmdt=4.240639e+00
# [ Info: step =  399  step_size=3.295377e-13  max_dmdt=1.043658e+00
# [ Info: step =  400  step_size=3.277087e-13  max_dmdt=7.563828e-01
# [ Info: step =  401  step_size=1.193801e-11  max_dmdt=7.575433e-01
# [ Info: step =  402  step_size=5.484521e-12  max_dmdt=7.653940e-01
# [ Info: step =  403  step_size=9.035488e-12  max_dmdt=6.559780e-01
# [ Info: step =  404  step_size=3.682019e-13  max_dmdt=3.753613e+00
# [ Info: step =  405  step_size=3.620031e-13  max_dmdt=9.261243e-01
# [ Info: step =  406  step_size=3.863551e-13  max_dmdt=7.757782e-01
# [ Info: step =  407  step_size=7.509650e-12  max_dmdt=7.964083e-01
# [ Info: step =  408  step_size=9.990978e-13  max_dmdt=8.428604e-01
# [ Info: step =  409  step_size=1.123317e-12  max_dmdt=9.924644e-01
# [ Info: step =  410  step_size=3.773495e-13  max_dmdt=9.952447e-01
# [ Info: step =  411  step_size=4.311998e-13  max_dmdt=7.240763e-01
# [ Info: step =  412  step_size=3.607954e-13  max_dmdt=6.552100e-01
# [ Info: step =  413  step_size=3.029662e-11  max_dmdt=6.507749e-01
# [ Info: step =  414  step_size=7.405038e-13  max_dmdt=1.048667e+00
# [ Info: step =  415  step_size=6.766880e-13  max_dmdt=1.007568e+00
# [ Info: step =  416  step_size=3.298937e-13  max_dmdt=7.839769e-01
# [ Info: step =  417  step_size=5.052210e-13  max_dmdt=7.735325e-01
# [ Info: step =  418  step_size=1.507589e-12  max_dmdt=7.494033e-01
# [ Info: step =  419  step_size=7.673831e-11  max_dmdt=6.656090e-01
# [ Info: step =  420  step_size=4.715091e-13  max_dmdt=4.819344e+00
# [ Info: step =  421  step_size=3.427505e-13  max_dmdt=2.503097e+00
# [ Info: step =  422  step_size=3.292546e-13  max_dmdt=9.894527e-01
# [ Info: step =  423  step_size=4.118538e-12  max_dmdt=8.832332e-01
# [ Info: step =  424  step_size=3.625519e-12  max_dmdt=1.013269e+00
# [ Info: step =  425  step_size=1.430699e-11  max_dmdt=5.899276e-01
# [ Info: step =  426  step_size=3.440801e-13  max_dmdt=8.966960e+00
# [ Info: step =  427  step_size=3.295987e-13  max_dmdt=2.244155e+00
# [ Info: step =  428  step_size=4.120513e-13  max_dmdt=1.929035e+00
# [ Info: step =  429  step_size=2.843940e-12  max_dmdt=1.633148e+00
# [ Info: step =  430  step_size=1.849453e-12  max_dmdt=6.722408e-01
# [ Info: step =  431  step_size=4.252081e-12  max_dmdt=6.284148e-01
# [ Info: step =  432  step_size=5.197579e-13  max_dmdt=2.124066e+00
# [ Info: step =  433  step_size=5.156606e-13  max_dmdt=8.544454e-01
# [ Info: step =  434  step_size=3.298570e-13  max_dmdt=6.278074e-01
# [ Info: step =  435  step_size=9.218356e-13  max_dmdt=4.992038e-01
# [ Info: step =  436  step_size=2.906352e-13  max_dmdt=4.905427e-01
# [ Info: step =  437  step_size=1.101609e-09  max_dmdt=4.898194e-01
# [ Info: step =  438  step_size=5.343562e-12  max_dmdt=5.392614e+00
# [ Info: step =  439  step_size=5.061179e-13  max_dmdt=6.226580e+01
# [ Info: step =  440  step_size=3.470045e-13  max_dmdt=3.491471e+01
# [ Info: step =  441  step_size=3.319440e-13  max_dmdt=4.343673e+00
# [ Info: step =  442  step_size=4.439134e-13  max_dmdt=2.921418e+00
# [ Info: step =  443  step_size=1.447556e-12  max_dmdt=2.206101e+00
# [ Info: step =  444  step_size=1.347444e-12  max_dmdt=1.150273e+00
# [ Info: step =  445  step_size=3.974599e-12  max_dmdt=1.272195e+00
# [ Info: step =  446  step_size=5.215074e-13  max_dmdt=3.343485e+00
# [ Info: step =  447  step_size=4.894535e-13  max_dmdt=2.009237e+00
# [ Info: step =  448  step_size=3.331630e-13  max_dmdt=1.326379e+00
# [ Info: step =  449  step_size=1.061630e-12  max_dmdt=9.119024e-01
# [ Info: step =  450  step_size=1.185273e-12  max_dmdt=9.295543e-01
# [ Info: step =  451  step_size=8.441999e-11  max_dmdt=9.138385e-01
# [ Info: step =  452  step_size=3.738071e-13  max_dmdt=3.039578e+01
# [ Info: step =  453  step_size=3.270895e-13  max_dmdt=4.940863e+00
# [ Info: step =  454  step_size=3.334429e-13  max_dmdt=1.107610e+00
# [ Info: step =  455  step_size=1.223989e-12  max_dmdt=9.132000e-01
# [ Info: step =  456  step_size=7.164162e-13  max_dmdt=7.984670e-01
# [ Info: step =  457  step_size=3.316296e-12  max_dmdt=6.049677e-01
# [ Info: step =  458  step_size=1.210922e-12  max_dmdt=6.107619e-01
# [ Info: step =  459  step_size=7.569446e-12  max_dmdt=5.750384e-01
# [ Info: step =  460  step_size=4.949594e-13  max_dmdt=2.437134e+00
# [ Info: step =  461  step_size=4.530954e-13  max_dmdt=1.264080e+00
# [ Info: step =  462  step_size=3.373686e-13  max_dmdt=6.521572e-01
# [ Info: step =  463  step_size=1.123774e-12  max_dmdt=5.416321e-01
# [ Info: step =  464  step_size=7.079897e-13  max_dmdt=5.403811e-01
# [ Info: step =  465  step_size=4.590406e-11  max_dmdt=5.440606e-01
# [ Info: step =  466  step_size=3.884464e-13  max_dmdt=6.608063e+00
# [ Info: step =  467  step_size=3.274938e-13  max_dmdt=1.450415e+00
# [ Info: step =  468  step_size=3.259067e-13  max_dmdt=6.809240e-01
# [ Info: step =  469  step_size=2.350325e-11  max_dmdt=6.609464e-01
# [ Info: step =  470  step_size=1.311191e-12  max_dmdt=2.567763e+00
# [ Info: step =  471  step_size=9.260601e-13  max_dmdt=1.418833e+00
# [ Info: step =  472  step_size=6.327993e-13  max_dmdt=1.099151e+00
# [ Info: step =  473  step_size=1.071221e-12  max_dmdt=8.988041e-01
# [ Info: step =  474  step_size=1.196094e-12  max_dmdt=7.802651e-01
# [ Info: step =  475  step_size=2.740048e-11  max_dmdt=7.275169e-01
# [ Info: step =  476  step_size=3.323550e-13  max_dmdt=1.090641e+01
# [ Info: step =  477  step_size=3.273515e-13  max_dmdt=1.123199e+00
# [ Info: step =  478  step_size=4.581441e-13  max_dmdt=9.525509e-01
# [ Info: step =  479  step_size=4.051685e-12  max_dmdt=8.173042e-01
# [ Info: step =  480  step_size=1.779743e-12  max_dmdt=1.006658e+00
# [ Info: step =  481  step_size=3.531610e-12  max_dmdt=7.546272e-01
# [ Info: step =  482  step_size=5.425472e-13  max_dmdt=2.068732e+00
# [ Info: step =  483  step_size=5.457468e-13  max_dmdt=6.203746e-01
# [ Info: step =  484  step_size=3.638617e-13  max_dmdt=6.676686e-01
# [ Info: step =  485  step_size=1.708795e-12  max_dmdt=6.581146e-01
# [ Info: step =  486  step_size=3.598770e-13  max_dmdt=6.653096e-01
# [ Info: step =  487  step_size=6.120699e-12  max_dmdt=6.688587e-01
# [ Info: step =  488  step_size=4.242502e-13  max_dmdt=6.835288e-01
# [ Info: step =  489  step_size=1.859185e-12  max_dmdt=6.793638e-01
# [ Info: step =  490  step_size=3.297223e-13  max_dmdt=6.695219e-01
# [ Info: step =  491  step_size=1.097781e-12  max_dmdt=6.735704e-01
# [ Info: step =  492  step_size=6.822866e-13  max_dmdt=6.738339e-01
# [ Info: step =  493  step_size=3.421364e-10  max_dmdt=6.738597e-01
# [ Info: step =  494  step_size=3.892872e-13  max_dmdt=1.486886e+01
# [ Info: step =  495  step_size=3.257083e-13  max_dmdt=3.136767e+00
# [ Info: step =  496  step_size=3.248179e-13  max_dmdt=6.768075e-01
# [ Info: step =  497  step_size=2.294249e-11  max_dmdt=6.607430e-01
# [ Info: step =  498  step_size=6.397850e-13  max_dmdt=1.314292e+00
# [ Info: step =  499  step_size=6.967703e-13  max_dmdt=9.902234e-01
# [ Info: step =  500  step_size=5.456317e-13  max_dmdt=8.144893e-01
# [ Info: step =  501  step_size=2.929563e-11  max_dmdt=7.658932e-01
# [ Info: step =  502  step_size=7.285129e-13  max_dmdt=2.355205e+00
# [ Info: step =  503  step_size=5.686650e-13  max_dmdt=1.601168e+00
# [ Info: step =  504  step_size=4.194624e-13  max_dmdt=1.151306e+00
# [ Info: step =  505  step_size=1.337314e-12  max_dmdt=9.945524e-01
# [ Info: step =  506  step_size=1.873581e-12  max_dmdt=6.735172e-01
# [ Info: step =  507  step_size=1.930947e-11  max_dmdt=7.616854e-01
# [ Info: step =  508  step_size=3.356099e-13  max_dmdt=1.711176e+01
# [ Info: step =  509  step_size=3.347326e-13  max_dmdt=1.097567e+00
# [ Info: step =  510  step_size=3.734870e-13  max_dmdt=8.336825e-01
# [ Info: step =  511  step_size=6.960843e-12  max_dmdt=7.799850e-01
# [ Info: step =  512  step_size=1.819497e-12  max_dmdt=7.351781e-01
# [ Info: step =  513  step_size=4.139688e-12  max_dmdt=8.430258e-01
# [ Info: step =  514  step_size=3.928172e-13  max_dmdt=5.024609e+00
# [ Info: step =  515  step_size=3.925699e-13  max_dmdt=1.090663e+00
# [ Info: step =  516  step_size=3.330109e-13  max_dmdt=6.468022e-01
# [ Info: step =  517  step_size=8.831765e-12  max_dmdt=5.633704e-01
# [ Info: step =  518  step_size=4.995458e-13  max_dmdt=9.012148e-01
# [ Info: step =  519  step_size=4.758293e-12  max_dmdt=6.110438e-01
# [ Info: step =  520  step_size=5.405989e-13  max_dmdt=1.583005e+00
# [ Info: step =  521  step_size=6.980324e-13  max_dmdt=8.787834e-01
# [ Info: step =  522  step_size=3.355764e-13  max_dmdt=9.269709e-01
# [ Info: step =  523  step_size=9.242468e-13  max_dmdt=5.794370e-01
# [ Info: step =  524  step_size=3.639408e-13  max_dmdt=5.907501e-01
# [ Info: step =  525  step_size=1.633875e-10  max_dmdt=5.668472e-01
# [ Info: step =  526  step_size=1.726020e-12  max_dmdt=2.654453e+00
# [ Info: step =  527  step_size=4.394008e-13  max_dmdt=8.419825e+00
# [ Info: step =  528  step_size=3.247878e-13  max_dmdt=3.374681e+00
# [ Info: step =  529  step_size=3.515156e-13  max_dmdt=7.014209e-01
# [ Info: step =  530  step_size=1.547299e-12  max_dmdt=6.360927e-01
# [ Info: step =  531  step_size=5.886515e-11  max_dmdt=6.733443e-01
# [ Info: step =  532  step_size=1.862520e-12  max_dmdt=4.136684e+00
# [ Info: step =  533  step_size=9.955865e-13  max_dmdt=4.065799e+00
# [ Info: step =  534  step_size=5.153356e-13  max_dmdt=2.874995e+00
# [ Info: step =  535  step_size=4.124518e-13  max_dmdt=1.648607e+00
# [ Info: step =  536  step_size=3.428080e-13  max_dmdt=7.925534e-01
# [ Info: step =  537  step_size=2.288263e-12  max_dmdt=6.061378e-01
# [ Info: step =  538  step_size=1.027822e-12  max_dmdt=6.023357e-01
# [ Info: step =  539  step_size=1.143207e-11  max_dmdt=6.678343e-01
# [ Info: step =  540  step_size=3.299592e-13  max_dmdt=7.490094e+00
# [ Info: step =  541  step_size=3.290143e-13  max_dmdt=6.145167e-01
# [ Info: step =  542  step_size=5.379760e-13  max_dmdt=5.601008e-01
# [ Info: step =  543  step_size=1.099114e-11  max_dmdt=5.547583e-01
# [ Info: step =  544  step_size=1.055760e-12  max_dmdt=1.251188e+00
# [ Info: step =  545  step_size=1.815425e-12  max_dmdt=5.693063e-01
# [ Info: step =  546  step_size=5.089924e-13  max_dmdt=8.970084e-01
# [ Info: step =  547  step_size=8.211006e-13  max_dmdt=6.383699e-01
# [ Info: step =  548  step_size=3.469724e-13  max_dmdt=7.425686e-01
# [ Info: step =  549  step_size=1.494958e-12  max_dmdt=5.450205e-01
# [ Info: step =  550  step_size=4.595190e-13  max_dmdt=5.553452e-01
# [ Info: step =  551  step_size=1.678093e-11  max_dmdt=5.439367e-01
# [ Info: step =  552  step_size=3.866183e-13  max_dmdt=2.153072e+00
# [ Info: step =  553  step_size=3.677558e-13  max_dmdt=7.287450e-01
# [ Info: step =  554  step_size=3.258230e-13  max_dmdt=5.348887e-01
# [ Info: step =  555  step_size=5.686630e-11  max_dmdt=5.306098e-01
# [ Info: step =  556  step_size=6.223067e-12  max_dmdt=6.556002e-01
# [ Info: step =  557  step_size=1.262402e-12  max_dmdt=4.025385e+00
# [ Info: step =  558  step_size=5.990570e-13  max_dmdt=4.391497e+00
# [ Info: step =  559  step_size=5.672585e-13  max_dmdt=1.914874e+00
# [ Info: step =  560  step_size=3.285959e-13  max_dmdt=1.455678e+00
# [ Info: step =  561  step_size=4.103328e-13  max_dmdt=4.944658e-01
# [ Info: step =  562  step_size=5.013694e-13  max_dmdt=4.907586e-01
# [ Info: step =  563  step_size=4.373487e-10  max_dmdt=4.913525e-01
# [ Info: step =  564  step_size=4.358240e-12  max_dmdt=9.221425e+00
# [ Info: step =  565  step_size=7.753022e-13  max_dmdt=3.662259e+01
# [ Info: step =  566  step_size=3.272001e-13  max_dmdt=4.900569e+01
# [ Info: step =  567  step_size=3.248437e-13  max_dmdt=3.106493e+00
# [ Info: step =  568  step_size=6.010613e-13  max_dmdt=2.783439e+00
# [ Info: step =  569  step_size=2.980301e-12  max_dmdt=2.246059e+00
# [ Info: step =  570  step_size=2.615354e-12  max_dmdt=9.102214e-01
# [ Info: step =  571  step_size=4.766795e-12  max_dmdt=8.228163e-01
# [ Info: step =  572  step_size=3.787619e-13  max_dmdt=5.477767e+00
# [ Info: step =  573  step_size=3.756292e-13  max_dmdt=1.035823e+00
# [ Info: step =  574  step_size=4.158140e-13  max_dmdt=8.368343e-01
# [ Info: step =  575  step_size=4.513777e-12  max_dmdt=8.181524e-01
# [ Info: step =  576  step_size=8.277929e-13  max_dmdt=9.571171e-01
# [ Info: step =  577  step_size=1.592726e-12  max_dmdt=7.804178e-01
# [ Info: step =  578  step_size=3.584732e-13  max_dmdt=7.665486e-01
# [ Info: step =  579  step_size=1.203085e-12  max_dmdt=7.862727e-01
# [ Info: step =  580  step_size=4.014338e-13  max_dmdt=7.776491e-01
# [ Info: step =  581  step_size=1.912783e-11  max_dmdt=7.753835e-01
# [ Info: step =  582  step_size=3.739982e-13  max_dmdt=1.046630e+00
# [ Info: step =  583  step_size=4.356940e-13  max_dmdt=7.521626e-01
# [ Info: step =  584  step_size=3.548979e-13  max_dmdt=7.437930e-01
# [ Info: step =  585  step_size=3.270876e-11  max_dmdt=7.395320e-01
# [ Info: step =  586  step_size=5.103061e-13  max_dmdt=9.409054e-01
# [ Info: step =  587  step_size=7.079100e-13  max_dmdt=5.830823e-01
# [ Info: step =  588  step_size=3.469367e-13  max_dmdt=6.437848e-01
# [ Info: step =  589  step_size=1.287255e-12  max_dmdt=6.526097e-01
# [ Info: step =  590  step_size=3.100608e-13  max_dmdt=6.625874e-01
# [ Info: step =  591  step_size=2.308273e-11  max_dmdt=6.611809e-01
# [ Info: step =  592  step_size=1.007929e-12  max_dmdt=5.840267e-01
# [ Info: step =  593  step_size=2.362004e-12  max_dmdt=6.424382e-01
# [ Info: step =  594  step_size=3.269745e-13  max_dmdt=2.606698e+00
# [ Info: step =  595  step_size=3.393571e-13  max_dmdt=5.917291e-01
# [ Info: step =  596  step_size=5.759379e-13  max_dmdt=6.012271e-01
# [ Info: step =  597  step_size=9.593209e-11  max_dmdt=6.094510e-01
# [ Info: step =  598  step_size=4.054660e-12  max_dmdt=8.036888e-01
# [ Info: step =  599  step_size=1.098967e-12  max_dmdt=3.433658e+00
# [ Info: step =  600  step_size=4.191685e-13  max_dmdt=6.305771e+00
# [ Info: step =  601  step_size=3.491543e-13  max_dmdt=1.991569e+00
# [ Info: step =  602  step_size=3.393279e-13  max_dmdt=6.095292e-01
# [ Info: step =  603  step_size=2.111390e-12  max_dmdt=5.345378e-01
# [ Info: step =  604  step_size=6.447720e-13  max_dmdt=5.501315e-01
# [ Info: step =  605  step_size=2.341811e-12  max_dmdt=4.751356e-01
# [ Info: step =  606  step_size=3.498033e-13  max_dmdt=5.898209e-01
# [ Info: step =  607  step_size=3.100537e-12  max_dmdt=4.722586e-01
# [ Info: step =  608  step_size=4.278097e-13  max_dmdt=5.570646e-01
# [ Info: step =  609  step_size=5.679225e-12  max_dmdt=4.846927e-01
# [ Info: step =  610  step_size=3.654109e-13  max_dmdt=1.042373e+00
# [ Info: step =  611  step_size=5.660090e-13  max_dmdt=5.279657e-01
# [ Info: step =  612  step_size=4.328303e-13  max_dmdt=4.969661e-01
# [ Info: step =  613  step_size=2.451947e-11  max_dmdt=4.743966e-01
# [ Info: step =  614  step_size=3.221703e-13  max_dmdt=1.965465e+00
# [ Info: step =  615  step_size=3.812864e-13  max_dmdt=6.395056e-01
# [ Info: step =  616  step_size=8.115216e-13  max_dmdt=5.052127e-01
# [ Info: step =  617  step_size=1.451807e-11  max_dmdt=4.791429e-01
# [ Info: step =  618  step_size=3.160420e-13  max_dmdt=5.788390e-01
# [ Info: step =  619  step_size=5.470895e-12  max_dmdt=4.828810e-01
# [ Info: step =  620  step_size=7.362391e-13  max_dmdt=7.773788e-01
# [ Info: step =  621  step_size=2.033506e-12  max_dmdt=5.120474e-01
# [ Info: step =  622  step_size=3.921466e-13  max_dmdt=7.290619e-01
# [ Info: step =  623  step_size=1.218338e-12  max_dmdt=5.063220e-01
# [ Info: step =  624  step_size=3.629787e-13  max_dmdt=6.098676e-01
# [ Info: step =  625  step_size=3.104003e-12  max_dmdt=4.876080e-01
# [ Info: step =  626  step_size=3.553492e-13  max_dmdt=6.154230e-01
# [ Info: step =  627  step_size=2.916839e-12  max_dmdt=4.817489e-01
# [ Info: step =  628  step_size=4.411471e-13  max_dmdt=5.735734e-01
# [ Info: step =  629  step_size=4.084288e-12  max_dmdt=5.043753e-01
# [ Info: step =  630  step_size=3.506197e-13  max_dmdt=1.011044e+00
# [ Info: step =  631  step_size=5.986934e-13  max_dmdt=4.922939e-01
# [ Info: step =  632  step_size=4.476199e-13  max_dmdt=4.915399e-01
# [ Info: step =  633  step_size=5.827513e-11  max_dmdt=4.856584e-01
# [ Info: step =  634  step_size=3.056934e-13  max_dmdt=3.379142e+00
# [ Info: step =  635  step_size=3.394635e-13  max_dmdt=6.478540e-01
# [ Info: step =  636  step_size=4.077969e-13  max_dmdt=5.323054e-01
# [ Info: step =  637  step_size=2.249217e-11  max_dmdt=4.972860e-01
# [ Info: step =  638  step_size=8.593857e-13  max_dmdt=2.509457e+00
# [ Info: step =  639  step_size=9.666730e-13  max_dmdt=6.295863e-01
# [ Info: step =  640  step_size=3.389707e-13  max_dmdt=8.316688e-01
# [ Info: step =  641  step_size=8.712862e-13  max_dmdt=4.943902e-01
# [ Info: step =  642  step_size=4.087892e-13  max_dmdt=4.973935e-01
# [ Info: step =  643  step_size=9.152990e-11  max_dmdt=4.951561e-01
# [ Info: step =  644  step_size=4.069494e-13  max_dmdt=2.967023e+00
# [ Info: step =  645  step_size=3.460411e-13  max_dmdt=9.944344e-01
# [ Info: step =  646  step_size=3.288764e-13  max_dmdt=4.993436e-01
# [ Info: step =  647  step_size=2.642312e-11  max_dmdt=4.911438e-01
# [ Info: step =  648  step_size=6.723133e-13  max_dmdt=9.477082e-01
# [ Info: step =  649  step_size=7.456031e-13  max_dmdt=4.846370e-01
# [ Info: step =  650  step_size=4.859701e-13  max_dmdt=4.933234e-01
# [ Info: step =  651  step_size=2.358408e-11  max_dmdt=4.860571e-01
# [ Info: step =  652  step_size=3.395822e-13  max_dmdt=2.769949e+00
# [ Info: step =  653  step_size=3.446692e-13  max_dmdt=5.879320e-01
# [ Info: step =  654  step_size=3.817155e-13  max_dmdt=5.256573e-01
# [ Info: step =  655  step_size=7.210177e-11  max_dmdt=5.010147e-01
# [ Info: step =  656  step_size=1.520562e-12  max_dmdt=4.869630e+00
# [ Info: step =  657  step_size=1.098878e-12  max_dmdt=1.871687e+00
# [ Info: step =  658  step_size=4.908430e-13  max_dmdt=2.926285e+00
# [ Info: step =  659  step_size=3.981834e-13  max_dmdt=1.645457e+00
# [ Info: step =  660  step_size=3.316406e-13  max_dmdt=7.722269e-01
# [ Info: step =  661  step_size=1.633033e-12  max_dmdt=6.936884e-01
# [ Info: step =  662  step_size=1.347900e-12  max_dmdt=5.109401e-01
# [ Info: step =  663  step_size=1.833674e-11  max_dmdt=5.120626e-01
# [ Info: step =  664  step_size=4.328654e-13  max_dmdt=5.526862e+00
# [ Info: step =  665  step_size=3.887756e-13  max_dmdt=1.848021e+00
# [ Info: step =  666  step_size=3.540837e-13  max_dmdt=7.333486e-01
# [ Info: step =  667  step_size=1.183975e-12  max_dmdt=6.199734e-01
# [ Info: step =  668  step_size=6.927658e-13  max_dmdt=5.715845e-01
# [ Info: step =  669  step_size=7.185213e-12  max_dmdt=5.314556e-01
# [ Info: step =  670  step_size=3.598946e-13  max_dmdt=2.004956e+00
# [ Info: step =  671  step_size=3.614066e-13  max_dmdt=5.858798e-01
# [ Info: step =  672  step_size=3.403254e-13  max_dmdt=4.863777e-01
# [ Info: step =  673  step_size=7.264580e-11  max_dmdt=4.864240e-01
# [ Info: step =  674  step_size=1.872709e-12  max_dmdt=3.649573e+00
# [ Info: step =  675  step_size=1.059155e-12  max_dmdt=2.232109e+00
# [ Info: step =  676  step_size=5.243043e-13  max_dmdt=3.239878e+00
# [ Info: step =  677  step_size=4.196952e-13  max_dmdt=1.837416e+00
# [ Info: step =  678  step_size=3.292845e-13  max_dmdt=9.552019e-01
# [ Info: step =  679  step_size=8.931782e-13  max_dmdt=7.332913e-01
# [ Info: step =  680  step_size=1.866928e-12  max_dmdt=6.285762e-01
# [ Info: step =  681  step_size=2.830661e-11  max_dmdt=5.244507e-01
# [ Info: step =  682  step_size=4.248646e-13  max_dmdt=5.683168e+00
# [ Info: step =  683  step_size=3.549490e-13  max_dmdt=2.123802e+00
# [ Info: step =  684  step_size=3.404962e-13  max_dmdt=1.185556e+00
# [ Info: step =  685  step_size=2.591732e-12  max_dmdt=1.086237e+00
# [ Info: step =  686  step_size=1.469681e-12  max_dmdt=5.722242e-01
# [ Info: step =  687  step_size=1.901196e-12  max_dmdt=6.229985e-01
# [ Info: step =  688  step_size=5.355484e-13  max_dmdt=1.515652e+00
# [ Info: step =  689  step_size=5.320249e-13  max_dmdt=8.870989e-01
# [ Info: step =  690  step_size=3.302359e-13  max_dmdt=6.797167e-01
# [ Info: step =  691  step_size=1.095172e-12  max_dmdt=5.135413e-01
# [ Info: step =  692  step_size=7.446784e-13  max_dmdt=5.159497e-01
# [ Info: step =  693  step_size=3.187736e-10  max_dmdt=5.146246e-01
# [ Info: step =  694  step_size=3.472780e-13  max_dmdt=1.987308e+01
# [ Info: step =  695  step_size=3.266515e-13  max_dmdt=2.490298e+00
# [ Info: step =  696  step_size=3.516246e-13  max_dmdt=2.033043e+00
# [ Info: step =  697  step_size=4.602388e-12  max_dmdt=1.848488e+00
# [ Info: step =  698  step_size=3.648823e-12  max_dmdt=6.378889e-01
# [ Info: step =  699  step_size=1.606981e-12  max_dmdt=1.461598e+00
# [ Info: step =  700  step_size=6.205546e-13  max_dmdt=2.067223e+00
# [ Info: step =  701  step_size=6.296261e-13  max_dmdt=7.238826e-01
# [ Info: step =  702  step_size=3.251391e-13  max_dmdt=7.048560e-01
# [ Info: step =  703  step_size=1.034784e-12  max_dmdt=5.227273e-01
# [ Info: step =  704  step_size=1.188418e-12  max_dmdt=5.229301e-01
# [ Info: step =  705  step_size=3.671225e-08  max_dmdt=5.153448e-01
# [ Info: step =  706  step_size=1.504300e-12  max_dmdt=6.249122e+02
# [ Info: step =  707  step_size=3.379468e-13  max_dmdt=2.103072e+03
# [ Info: step =  708  step_size=3.247162e-13  max_dmdt=1.358639e+02
# [ Info: step =  709  step_size=5.919994e-13  max_dmdt=9.982110e+01
# [ Info: step =  710  step_size=3.128069e-12  max_dmdt=7.644665e+01
# [ Info: step =  711  step_size=9.654890e-12  max_dmdt=4.125256e+01
# [ Info: step =  712  step_size=1.340388e-12  max_dmdt=3.944819e+02
# [ Info: step =  713  step_size=4.457414e-13  max_dmdt=5.088133e+02
# [ Info: step =  714  step_size=3.344227e-13  max_dmdt=1.138732e+02
# ...
# [ Info: step = 1354  step_size=8.783074e-13  max_dmdt=3.780823e+00
# [ Info: step = 1355  step_size=1.231666e-12  max_dmdt=2.399533e+00
# [ Info: step = 1356  step_size=4.054299e-13  max_dmdt=1.820030e+00
# [ Info: step = 1357  step_size=3.783900e-13  max_dmdt=8.191062e-01
# [ Info: step = 1358  step_size=3.318775e-13  max_dmdt=8.107900e-01
# [ Info: step = 1359  step_size=1.830209e-11  max_dmdt=8.022267e-01
# [ Info: step = 1360  step_size=1.844687e-12  max_dmdt=1.651992e+00
# [ Info: step = 1361  step_size=1.806866e-12  max_dmdt=1.286207e+00
# [ Info: step = 1362  step_size=4.403905e-13  max_dmdt=2.968865e+00
# [ Info: step = 1363  step_size=4.070669e-13  max_dmdt=1.099159e+00
# [ Info: step = 1364  step_size=3.403573e-13  max_dmdt=9.758015e-01
# [ Info: step = 1365  step_size=3.098602e-12  max_dmdt=9.563885e-01
# [ Info: step = 1366  step_size=7.004892e-13  max_dmdt=9.259500e-01
# [ Info: step = 1367  step_size=4.644780e-12  max_dmdt=9.774511e-01
# [ Info: step = 1368  step_size=3.357823e-13  max_dmdt=1.571328e+00
# [ Info: step = 1369  step_size=3.962170e-13  max_dmdt=9.604493e-01
# [ Info: step = 1370  step_size=4.445072e-13  max_dmdt=9.824153e-01
# [ Info: step = 1371  step_size=2.156362e-10  max_dmdt=9.924030e-01
# [ Info: step = 1372  step_size=1.711620e-12  max_dmdt=4.161919e+00
# [ Info: step = 1373  step_size=4.621833e-13  max_dmdt=1.274591e+01
# [ Info: step = 1374  step_size=3.298471e-13  max_dmdt=5.323800e+00
# [ Info: step = 1375  step_size=3.464806e-13  max_dmdt=1.956317e+00
# [ Info: step = 1376  step_size=6.828024e-13  max_dmdt=2.016953e+00
# [ Info: step = 1377  step_size=2.207692e-11  max_dmdt=2.062896e+00
# [ Info: step = 1378  step_size=2.369847e-12  max_dmdt=3.497522e+00
# [ Info: step = 1379  step_size=1.136845e-12  max_dmdt=4.874159e+00
# [ Info: step = 1380  step_size=3.720946e-13  max_dmdt=8.337152e+00
# [ Info: step = 1381  step_size=3.399625e-13  max_dmdt=2.206402e+00
# [ Info: step = 1382  step_size=3.504932e-13  max_dmdt=1.599230e+00
# [ Info: step = 1383  step_size=7.425140e-12  max_dmdt=1.558516e+00
# [ Info: step = 1384  step_size=7.994662e-13  max_dmdt=3.287849e+00
# [ Info: step = 1385  step_size=8.927275e-13  max_dmdt=1.785990e+00
# [ Info: step = 1386  step_size=5.080717e-13  max_dmdt=1.699865e+00
# [ Info: step = 1387  step_size=2.309407e-12  max_dmdt=1.510088e+00
# [ Info: step = 1388  step_size=3.561896e-13  max_dmdt=1.401895e+00
# [ Info: step = 1389  step_size=6.398495e-13  max_dmdt=1.429890e+00
# [ Info: step = 1390  step_size=4.076220e-13  max_dmdt=1.441775e+00
# [ Info: step = 1391  step_size=2.640405e-11  max_dmdt=1.434029e+00
# [ Info: step = 1392  step_size=1.541594e-12  max_dmdt=1.988667e+00
# [ Info: step = 1393  step_size=3.719654e-13  max_dmdt=6.797625e+00
# [ Info: step = 1394  step_size=3.238514e-13  max_dmdt=1.222066e+00
# [ Info: step = 1395  step_size=4.723156e-13  max_dmdt=1.022469e+00
# [ Info: step = 1396  step_size=9.013733e-12  max_dmdt=1.009800e+00
# [ Info: step = 1397  step_size=1.121948e-10  max_dmdt=8.761889e-01
# [ Info: step = 1398  step_size=2.126894e-12  max_dmdt=1.156044e+01
# [ Info: step = 1399  step_size=5.716113e-13  max_dmdt=3.262556e+01
# [ Info: step = 1400  step_size=5.459847e-13  max_dmdt=1.800709e+00
# [ Info: step = 1401  step_size=4.075327e-13  max_dmdt=1.158033e+00
# [ Info: step = 1402  step_size=3.303921e-13  max_dmdt=5.494008e-01
# [ Info: step = 1403  step_size=1.156493e-12  max_dmdt=5.244479e-01
# [ Info: step = 1404  step_size=1.064854e-12  max_dmdt=5.094574e-01
# [ Info: step = 1405  step_size=2.194245e-10  max_dmdt=5.126475e-01
# [ Info: step = 1406  step_size=3.278510e-13  max_dmdt=1.823002e+01
# [ Info: step = 1407  step_size=3.254259e-13  max_dmdt=1.486120e+00
# [ Info: step = 1408  step_size=5.695644e-13  max_dmdt=1.281852e+00
# [ Info: step = 1409  step_size=4.783457e-12  max_dmdt=1.213377e+00
# [ Info: step = 1410  step_size=1.599254e-12  max_dmdt=1.309199e+00
# [ Info: step = 1411  step_size=3.604058e-12  max_dmdt=1.632735e+00
# [ Info: step = 1412  step_size=6.998083e-13  max_dmdt=2.658077e+00
# [ Info: step = 1413  step_size=7.543091e-13  max_dmdt=1.213291e+00
# [ Info: step = 1414  step_size=3.421511e-13  max_dmdt=1.165247e+00
# [ Info: step = 1415  step_size=7.324449e-13  max_dmdt=1.169051e+00
# [ Info: step = 1416  step_size=5.842924e-13  max_dmdt=1.174790e+00
# [ Info: step = 1417  step_size=4.916739e-11  max_dmdt=1.163833e+00
# [ Info: step = 1418  step_size=5.994752e-13  max_dmdt=6.260576e+00
# [ Info: step = 1419  step_size=3.265178e-13  max_dmdt=5.289137e+00
# [ Info: step = 1420  step_size=3.238421e-13  max_dmdt=5.878333e-01
# [ Info: step = 1421  step_size=3.001108e-11  max_dmdt=5.821267e-01
# [ Info: step = 1422  step_size=8.761758e-12  max_dmdt=5.564893e-01
# [ Info: step = 1423  step_size=1.065425e-12  max_dmdt=7.645439e+00
# [ Info: step = 1424  step_size=4.727379e-13  max_dmdt=1.078224e+01
# [ Info: step = 1425  step_size=4.489850e-13  max_dmdt=2.793275e+00
# [ Info: step = 1426  step_size=3.767603e-13  max_dmdt=9.153529e-01
# [ Info: step = 1427  step_size=9.882088e-13  max_dmdt=3.437064e-01
# [ Info: step = 1428  step_size=1.345455e-12  max_dmdt=3.393611e-01
# [ Info: step = 1429  step_size=3.863132e-11  max_dmdt=3.699958e-01
# [ Info: step = 1430  step_size=3.954893e-13  max_dmdt=1.422998e+01
# [ Info: step = 1431  step_size=3.572728e-13  max_dmdt=1.490865e+00
# [ Info: step = 1432  step_size=3.555883e-13  max_dmdt=3.370628e-01
# [ Info: step = 1433  step_size=3.750078e-12  max_dmdt=2.666839e-01
# [ Info: step = 1434  step_size=1.663430e-12  max_dmdt=3.489001e-01
# [ Info: step = 1435  step_size=1.635805e-12  max_dmdt=6.161436e-01
# [ Info: step = 1436  step_size=4.867635e-13  max_dmdt=1.104259e+00
# [ Info: step = 1437  step_size=5.006236e-13  max_dmdt=2.601178e-01
# [ Info: step = 1438  step_size=3.396686e-13  max_dmdt=2.507163e-01
# [ Info: step = 1439  step_size=2.909679e-12  max_dmdt=2.496532e-01
# [ Info: step = 1440  step_size=1.107632e-11  max_dmdt=2.450099e-01
# [ Info: step = 1441  step_size=6.529551e-11  max_dmdt=3.383476e-01
# [ Info: step = 1442  step_size=3.351365e-13  max_dmdt=6.317125e+01
# [ Info: step = 1443  step_size=3.341048e-13  max_dmdt=3.419739e+00
# [ Info: step = 1444  step_size=4.822104e-13  max_dmdt=1.098006e+00
# [ Info: step = 1445  step_size=5.624146e-13  max_dmdt=4.676780e-01
# [ Info: step = 1446  step_size=6.373820e-13  max_dmdt=3.932248e-01
# [ Info: step = 1447  step_size=1.260197e-11  max_dmdt=3.817875e-01
# [ Info: step = 1448  step_size=6.656856e-13  max_dmdt=4.979518e-01
# [ Info: step = 1449  step_size=5.077688e-13  max_dmdt=4.110950e-01
# [ Info: step = 1450  step_size=3.418352e-13  max_dmdt=3.630863e-01
# [ Info: step = 1451  step_size=8.137549e-13  max_dmdt=3.717919e-01
# [ Info: step = 1452  step_size=8.020690e-13  max_dmdt=3.799085e-01
# [ Info: step = 1453  step_size=4.829536e-11  max_dmdt=3.848970e-01
# [ Info: step = 1454  step_size=3.624298e-13  max_dmdt=3.086366e+00
# [ Info: step = 1455  step_size=3.320754e-13  max_dmdt=4.749864e-01
# [ Info: step = 1456  step_size=3.379173e-13  max_dmdt=4.720629e-01
# [ Info: step = 1457  step_size=6.018181e-12  max_dmdt=4.612733e-01
# [ Info: step = 1458  step_size=2.299972e-12  max_dmdt=3.924341e-01
# [ Info: step = 1459  step_size=2.509830e-12  max_dmdt=5.914071e-01
# [ Info: step = 1460  step_size=5.344340e-13  max_dmdt=1.070851e+00
# [ Info: step = 1461  step_size=4.523894e-13  max_dmdt=4.727683e-01
# [ Info: step = 1462  step_size=3.617333e-13  max_dmdt=3.946568e-01
# [ Info: step = 1463  step_size=2.628218e-12  max_dmdt=3.936313e-01
# [ Info: step = 1464  step_size=9.479396e-13  max_dmdt=4.101672e-01
# [ Info: step = 1465  step_size=3.670358e-12  max_dmdt=4.089985e-01
# [ Info: step = 1466  step_size=3.257657e-13  max_dmdt=1.126904e+00
# [ Info: step = 1467  step_size=3.336320e-13  max_dmdt=3.872333e-01
# [ Info: step = 1468  step_size=4.717853e-13  max_dmdt=3.930434e-01
# [ Info: step = 1469  step_size=1.779453e-10  max_dmdt=3.949958e-01
# [ Info: step = 1470  step_size=4.747826e-12  max_dmdt=1.010684e+00
# [ Info: step = 1471  step_size=1.159417e-12  max_dmdt=3.667898e+00
# [ Info: step = 1472  step_size=4.701929e-13  max_dmdt=5.495226e+00
# [ Info: step = 1473  step_size=3.898469e-13  max_dmdt=9.475450e-01
# [ Info: step = 1474  step_size=3.519796e-13  max_dmdt=2.268727e-01
# [ Info: step = 1475  step_size=6.465513e-13  max_dmdt=1.915096e-01
# [ Info: step = 1476  step_size=1.045875e-12  max_dmdt=1.889341e-01
# [ Info: step = 1477  step_size=9.267244e-12  max_dmdt=2.040212e-01
# [ Info: step = 1478  step_size=3.479477e-13  max_dmdt=8.534227e-01
# [ Info: step = 1479  step_size=3.326366e-13  max_dmdt=2.323114e-01
# [ Info: step = 1480  step_size=3.588183e-13  max_dmdt=2.264271e-01
# [ Info: step = 1481  step_size=1.590180e-11  max_dmdt=2.198673e-01
# [ Info: step = 1482  step_size=1.724606e-12  max_dmdt=2.163368e-01
# [ Info: step = 1483  step_size=1.608652e-12  max_dmdt=2.122959e-01
# [ Info: step = 1484  step_size=4.581464e-13  max_dmdt=2.494483e-01
# [ Info: step = 1485  step_size=4.666861e-13  max_dmdt=1.668829e-01
# [ Info: step = 1486  step_size=3.284207e-13  max_dmdt=1.718953e-01
# [ Info: step = 1487  step_size=4.870665e-12  max_dmdt=1.724683e-01
# [ Info: step = 1488  step_size=6.175110e-12  max_dmdt=1.731135e-01
# [ Info: step = 1489  step_size=3.768884e-11  max_dmdt=1.577800e-01
# [ Info: step = 1490  step_size=3.450298e-13  max_dmdt=1.209966e+01
# [ Info: step = 1491  step_size=3.336801e-13  max_dmdt=1.113724e+00
# [ Info: step = 1492  step_size=4.290640e-13  max_dmdt=5.474973e-01
# [ Info: step = 1493  step_size=1.096284e-12  max_dmdt=3.319732e-01
# [ Info: step = 1494  step_size=1.155114e-12  max_dmdt=1.797034e-01
# [ Info: step = 1495  step_size=1.791815e-12  max_dmdt=1.426957e-01
# [ Info: step = 1496  step_size=3.617225e-13  max_dmdt=2.402023e-01
# [ Info: step = 1497  step_size=3.908955e-13  max_dmdt=1.147654e-01
# [ Info: step = 1498  step_size=3.838395e-13  max_dmdt=1.176212e-01
# [ Info: step = 1499  step_size=3.446434e-11  max_dmdt=1.194386e-01
# [ Info: step = 1500  step_size=7.298151e-13  max_dmdt=1.953525e-01
# [ Info: step = 1501  step_size=7.086478e-13  max_dmdt=1.823981e-01
# [ Info: step = 1502  step_size=3.253014e-13  max_dmdt=2.009300e-01
# [ Info: step = 1503  step_size=4.556893e-13  max_dmdt=1.026071e-01
# [ Info: step = 1504  step_size=3.662534e-13  max_dmdt=1.009718e-01
# [ Info: step = 1505  step_size=1.876506e-09  max_dmdt=1.001278e-01
# [ Info: step = 1506  step_size=2.601064e-12  max_dmdt=3.237675e+00
# [ Info: step = 1507  step_size=1.483145e-12  max_dmdt=3.148384e+00
# [ Info: step = 1508  step_size=5.514221e-13  max_dmdt=5.347396e+00
# [ Info: step = 1509  step_size=3.522809e-13  max_dmdt=3.870888e+00
# [ Info: step = 1510  step_size=3.251983e-13  max_dmdt=1.424891e+00
# [ Info: step = 1511  step_size=3.630620e-12  max_dmdt=1.316722e+00
# [ Info: step = 1512  step_size=1.191385e-12  max_dmdt=1.485666e+00
# [ Info: step = 1513  step_size=4.437442e-12  max_dmdt=1.262127e+00
# [ Info: step = 1514  step_size=8.907590e-13  max_dmdt=2.005297e+00
# [ Info: step = 1515  step_size=1.327317e-12  max_dmdt=1.168629e+00
# [ Info: step = 1516  step_size=3.302377e-13  max_dmdt=2.682098e+00
# [ Info: step = 1517  step_size=3.815228e-13  max_dmdt=1.084149e+00
# [ Info: step = 1518  step_size=5.126363e-13  max_dmdt=1.092895e+00
# [ Info: step = 1519  step_size=1.042243e-10  max_dmdt=1.083202e+00
# [ Info: step = 1520  step_size=2.371275e-11  max_dmdt=1.818623e+00
# [ Info: step = 1521  step_size=3.808013e-13  max_dmdt=1.136635e+02
# [ Info: step = 1522  step_size=3.277843e-13  max_dmdt=2.027054e+01
# [ Info: step = 1523  step_size=3.441724e-13  max_dmdt=3.557318e+00
# [ Info: step = 1524  step_size=7.414149e-13  max_dmdt=2.249423e+00
# [ Info: step = 1525  step_size=8.517439e-13  max_dmdt=9.738594e-01
# [ Info: step = 1526  step_size=6.877484e-13  max_dmdt=9.420375e-01
# [ Info: step = 1527  step_size=1.574869e-11  max_dmdt=9.951988e-01
# [ Info: step = 1528  step_size=3.865750e-13  max_dmdt=2.357832e+00
# [ Info: step = 1529  step_size=3.846063e-13  max_dmdt=1.030671e+00
# [ Info: step = 1530  step_size=3.386328e-13  max_dmdt=1.067927e+00
# [ Info: step = 1531  step_size=1.939315e-11  max_dmdt=1.069978e+00
# [ Info: step = 1532  step_size=1.358650e-12  max_dmdt=1.480566e+00
# [ Info: step = 1533  step_size=1.448899e-12  max_dmdt=1.560574e+00
# [ Info: step = 1534  step_size=3.811502e-13  max_dmdt=2.258748e+00
# [ Info: step = 1535  step_size=3.730489e-13  max_dmdt=1.136213e+00
# [ Info: step = 1536  step_size=3.633371e-13  max_dmdt=1.092144e+00
# [ Info: step = 1537  step_size=1.431005e-11  max_dmdt=1.080952e+00
# [ Info: step = 1538  step_size=7.600118e-13  max_dmdt=1.389864e+00
# [ Info: step = 1539  step_size=7.848439e-13  max_dmdt=1.158973e+00
# [ Info: step = 1540  step_size=3.576077e-13  max_dmdt=1.072516e+00
# [ Info: step = 1541  step_size=6.898482e-13  max_dmdt=1.087982e+00
# [ Info: step = 1542  step_size=3.892263e-13  max_dmdt=1.095107e+00
# [ Info: step = 1543  step_size=2.462294e-11  max_dmdt=1.092014e+00
# [ Info: step = 1544  step_size=7.387216e-13  max_dmdt=1.169398e+00
# [ Info: step = 1545  step_size=4.579501e-13  max_dmdt=1.406577e+00
# [ Info: step = 1546  step_size=3.249521e-13  max_dmdt=1.032732e+00
# [ Info: step = 1547  step_size=7.350917e-13  max_dmdt=1.034482e+00
# [ Info: step = 1548  step_size=2.865303e-12  max_dmdt=1.038605e+00
# [ Info: step = 1549  step_size=6.294087e-11  max_dmdt=1.049322e+00
# [ Info: step = 1550  step_size=6.743682e-13  max_dmdt=3.271487e+00
# [ Info: step = 1551  step_size=3.425829e-13  max_dmdt=3.463768e+00
# [ Info: step = 1552  step_size=3.245405e-13  max_dmdt=9.992509e-01
# [ Info: step = 1553  step_size=2.047269e-12  max_dmdt=9.620180e-01
# [ Info: step = 1554  step_size=2.202193e-12  max_dmdt=9.015548e-01
# [ Info: step = 1555  step_size=4.008862e-11  max_dmdt=9.125196e-01
# [ Info: step = 1556  step_size=5.358700e-13  max_dmdt=7.265560e+00
# [ Info: step = 1557  step_size=5.148067e-13  max_dmdt=1.384356e+00
# [ Info: step = 1558  step_size=3.476489e-13  max_dmdt=8.611929e-01
# [ Info: step = 1559  step_size=4.915121e-13  max_dmdt=6.114999e-01
# [ Info: step = 1560  step_size=8.406319e-13  max_dmdt=6.046504e-01
# [ Info: step = 1561  step_size=1.376333e-11  max_dmdt=6.173779e-01
# [ Info: step = 1562  step_size=8.355271e-13  max_dmdt=1.577573e+00
# [ Info: step = 1563  step_size=3.495723e-13  max_dmdt=2.478525e+00
# [ Info: step = 1564  step_size=3.242785e-13  max_dmdt=6.843389e-01
# [ Info: step = 1565  step_size=1.420004e-12  max_dmdt=6.742760e-01
# [ Info: step = 1566  step_size=3.823899e-12  max_dmdt=6.452020e-01
# [ Info: step = 1567  step_size=2.150894e-11  max_dmdt=6.222237e-01
# [ Info: step = 1568  step_size=4.303992e-13  max_dmdt=5.595496e+00
# [ Info: step = 1569  step_size=4.199306e-13  max_dmdt=4.662727e-01
# [ Info: step = 1570  step_size=3.585697e-13  max_dmdt=4.426939e-01
# [ Info: step = 1571  step_size=5.524250e-12  max_dmdt=4.462283e-01
# [ Info: step = 1572  step_size=2.507848e-12  max_dmdt=4.807883e-01
# [ Info: step = 1573  step_size=1.794110e-12  max_dmdt=8.434443e-01
# [ Info: step = 1574  step_size=3.319026e-13  max_dmdt=3.295077e+00
# [ Info: step = 1575  step_size=3.282139e-13  max_dmdt=5.938057e-01
# [ Info: step = 1576  step_size=4.971031e-13  max_dmdt=4.524327e-01
# [ Info: step = 1577  step_size=5.106128e-12  max_dmdt=4.427500e-01
# [ Info: step = 1578  step_size=1.322670e-12  max_dmdt=4.117763e-01
# [ Info: step = 1579  step_size=3.047260e-12  max_dmdt=4.774399e-01
# [ Info: step = 1580  step_size=5.663473e-13  max_dmdt=9.873806e-01
# [ Info: step = 1581  step_size=6.062659e-13  max_dmdt=3.886999e-01
# [ Info: step = 1582  step_size=3.285396e-13  max_dmdt=3.986180e-01
# [ Info: step = 1583  step_size=1.067986e-12  max_dmdt=3.958397e-01
# [ Info: step = 1584  step_size=4.843976e-12  max_dmdt=3.910743e-01
# [ Info: step = 1585  step_size=1.003177e-10  max_dmdt=3.810444e-01
# [ Info: step = 1586  step_size=3.398907e-13  max_dmdt=2.134156e+01
# [ Info: step = 1587  step_size=3.307760e-13  max_dmdt=1.273302e+00
# [ Info: step = 1588  step_size=3.670594e-13  max_dmdt=2.437898e-01
# [ Info: step = 1589  step_size=4.908190e-13  max_dmdt=1.080385e-01
# [ Info: step = 1590  step_size=5.550569e-13  max_dmdt=9.669774e-02
# [ Info: max_dmdt is less than stopping_dmdt=0.1, Done!

# %% [markdown]
# After running the simulation, the energy text file ('skx_fm_energy.txt') and the corresponding
# distance text file ('skx_fm_distance.txt') are generated.

# %% [markdown]
# We define a function to extract the data for plotting.

# %%
function extract_data(; id=1)
    energy = readdlm("assets/skx_fm_energy.txt"; skipstart=2)
    dms = readdlm("assets/skx_fm_distance.txt"; skipstart=2)
    xs = zeros(length(dms[1, 1:end]))
    for i in 2:length(xs)
        xs[i] = sum(dms[id, 2:i])
    end

    et = energy[id, 2:end]
    e0 = minimum(et)
    energy_eV = (et .- e0) / meV

    spline = CubicSpline(xs, energy_eV)

    xs2 = range(xs[1], xs[end], 100)
    energy2 = spline[xs2]

    return xs, energy_eV, xs2, energy2
end

function plot_energy()
    fig = Figure(; resolution=(800, 480))
    ax = Axis(fig[1, 1]; xlabel="Distance (a.u.)", ylabel="Energy (meV)")

    xs, energy, xs2, energy2 = extract_data(; id=1)
    scatter!(ax, xs, energy; markersize=6, label="Initial energy path")
    lines!(ax, xs2, energy2)

    xs, energy, xs2, energy2 = extract_data(; id=500)
    scatter!(ax, xs, energy; markersize=6, label="Minimal energy path")
    lines!(ax, xs2, energy2)
    #linescatter!(ax, data[:,2]*1e9, data[:,5], markersize = 6)
    #linescatter!(ax, data[:,2]*1e9, data[:,6], markersize = 6)

    axislegend()

    save("energy.png", fig)

    return fig
end

plot_energy()
# Out:
# ┌ Warning: Found `resolution` in the theme when creating a `Scene`. The `resolution` keyword for `Scene`s and `Figure`s has been deprecated. Use `Figure(; size = ...` or `Scene(; size = ...)` instead, which better reflects that this is a unitless size and not a pixel resolution. The key could also come from `set_theme!` calls or related theming functions.
# └ @ Makie ~/.julia/packages/Makie/aJUtI/src/scenes.jl:259
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
